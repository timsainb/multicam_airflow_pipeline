# %%
# %load_ext autoreload
# %autoreload 2

# %%
from multicamera_airflow_pipeline.jonah_241112.sync.sync_cameras import CameraSynchronizer

# %%
# rec_dir = "/n/groups/datta/Jonah/tmp//24-07-01-10-45-20-017041"
# rec_dir = "/n/groups/datta/Jonah/20231003_vlPAG_npx/raw_data/J07501/20240815_J07501_6cam/24-08-15-11-10-51-020094"
# fps = 90

rec_dir = "/n/groups/datta/Jonah/20240206_methimazole_sniffing/20240206_6cam/data/J04502/20240426_J04502"
output_dir = "/n/groups/datta/Jonah/tmp"
fps = 120

cs = CameraSynchronizer(
    rec_dir,
    output_dir,
    fps,
)

# %%
cs.run()

# %%
from multicamera_airflow_pipeline.jonah_241112.calibration import Calibrator
import yaml

# %%
calibration_video_directory = "/n/groups/datta/Jonah/2024_6cam_calibrations/JP_219_rig/calibration/20240426_calibration"
calibration_output_directory = "/n/groups/datta/Jonah/2024_6cam_calibrations/JP_219_rig/calibration/20240426_calibration_output"
config_file = "/n/groups/datta/tim_sainburg/projects/multicamera_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/default_config_v2.yaml"
config = yaml.safe_load(open(config_file, 'r'))
c = Calibrator(calibration_video_directory,
        calibration_output_directory,
        **config["camera_calibration"]
)

# %%
c.run()
# Out:
# > /n/groups/datta/tim_sainburg/projects/multicamera_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/calibration.py(66)find_videos()
#      64         try:
#      65             import pdb; pdb.set_trace()
# ---> 66             self.video_paths = {
#      67                 camera: [
#      68                     list(Path(f"{self.calibration_video_directory}").glob(f"*.{camera}.mp4"))[0]
#
# ['top', 'side1', 'side2', 'side3', 'side4', 'bottom']
# > /n/groups/datta/tim_sainburg/projects/multicamera_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/calibration.py(70)find_videos()
#      68                     list(Path(f"{self.calibration_video_directory}").glob(f"*.{camera}.mp4"))[0]
#      69                 ]
# ---> 70                 for camera in self.camera_names
#      71             }
#      72         except:
#
# > /n/groups/datta/tim_sainburg/projects/multicamera_airflow_pipeline/multicamera_airflow_pipeline/jonah_241112/calibration.py(66)find_videos()
# ...
