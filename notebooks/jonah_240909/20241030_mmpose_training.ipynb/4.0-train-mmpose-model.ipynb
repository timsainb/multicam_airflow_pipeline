# %% [markdown]
# ### Train an MMPose Network
# - note that I am using the conda env at /n/groups/datta/tim_sainburg/conda_envs/openmmlab

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
from pathlib import Path
import sys
from datetime import datetime

# %%
pretrained_model_directory = Path("/n/groups/datta/tim_sainburg/datasets/scratch/pretrained_mm_models")

# %% [markdown]
# ### Download checkpoint for a pretrained model (if desired)
# Alternatively, use a previous mouse model as a pretrained model

# %%
pretrained_model_directory = Path("/n/groups/datta/tim_sainburg/datasets/scratch/pretrained_mm_models")
pretrained_model_directory.mkdir(parents=True, exist_ok=True)

# %%
# find models here: https://github.com/open-mmlab/mmpose/tree/main/configs
pretrain_model = "rtmpose-m_8xb64-210e_ap10k-256x256"

# %%
command = f"source activate {Path(sys.executable).parents[1]}; mim download mmpose --config {pretrain_model} --dest {pretrained_model_directory.as_posix()}"
print(command)
# Out:
# source activate /n/groups/datta/tim_sainburg/conda_envs/openmmlab; mim download mmpose --config rtmpose-m_8xb64-210e_ap10k-256x256 --dest /n/groups/datta/tim_sainburg/datasets/scratch/pretrained_mm_models

# %%
# !{command}
# Out:
# /bin/bash: activate: No such file or directory
# processing rtmpose-m_8xb64-210e_ap10k-256x256...
# rtmpose-m_simcc-ap10k_pt-aic-coco_210e-256x256-7a041aa1_20230206.pth exists in /n/groups/datta/tim_sainburg/datasets/scratch/pretrained_mm_models
# Traceback (most recent call last):
#   File "/n/groups/datta/tim_sainburg/conda_envs/openmmlab/bin/mim", line 8, in <module>
#     sys.exit(cli())
#   File "/n/groups/datta/tim_sainburg/conda_envs/openmmlab/lib/python3.10/site-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "/n/groups/datta/tim_sainburg/conda_envs/openmmlab/lib/python3.10/site-packages/click/core.py", line 1078, in main
#     rv = self.invoke(ctx)
#   File "/n/groups/datta/tim_sainburg/conda_envs/openmmlab/lib/python3.10/site-packages/click/core.py", line 1688, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/n/groups/datta/tim_sainburg/conda_envs/openmmlab/lib/python3.10/site-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/n/groups/datta/tim_sainburg/conda_envs/openmmlab/lib/python3.10/site-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "/n/groups/datta/tim_sainburg/conda_envs/openmmlab/lib/python3.10/site-packages/mim/commands/download.py", line 70, in cli
#     download(package, configs, dest_root, check_certificate, dataset)
#   File "/n/groups/datta/tim_sainburg/conda_envs/openmmlab/lib/python3.10/site-packages/mim/commands/download.py", line 107, in download
#     return _download_configs(package, configs, dest_root,
#   File "/n/groups/datta/tim_sainburg/conda_envs/openmmlab/lib/python3.10/site-packages/mim/commands/download.py", line 182, in _download_configs
#     config_obj.dump(saved_config_path)
#   File "/n/groups/datta/tim_sainburg/conda_envs/openmmlab/lib/python3.10/site-packages/mmengine/config/config.py", line 1568, in dump
#     with open(file, 'w', encoding='utf-8') as f:
# PermissionError: [Errno 13] Permission denied: '/n/groups/datta/tim_sainburg/datasets/scratch/pretrained_mm_models/rtmpose-m_8xb64-210e_ap10k-256x256.py'

# %%
# !ls {pretrained_model_directory.as_posix()}
# Out:
# rtmdet_s_8xb32-300e_coco_20220905_161602-387a891e.pth
# rtmdet_s_8xb32-300e_coco.py
# rtmpose-m_8xb64-210e_ap10k-256x256.py
# rtmpose-m_simcc-ap10k_pt-aic-coco_210e-256x256-7a041aa1_20230206.pth

# %%
pretrained_model_directory
# Out:
# PosixPath('/n/groups/datta/tim_sainburg/datasets/scratch/pretrained_mm_models')

# %% [markdown]
# ### Parameters and dataset

# %%
model_name = 'rtmpose-m_8xb64-210e_ap10k-256x256'

# Where the COCO format dataset is located (created in the previous notebook)
# dataset_directory = Path("/n/groups/datta/tim_sainburg/projects/24-04-02-neuropixels-chronic/data/keypoints/coco-trainingsets/240408-mmpose-multianimal-chronic_v3/")
dataset_directory = Path("/n/groups/datta/6cam_keypoint_networks/training_data/JP_CW_scale_annos/COCO_format/")

# this file contains info about the dataset (keypoints, skeleton, etc) needed for traiing
# dataset_info_loc =  Path("/n/groups/datta/tim_sainburg/projects/multicamera_airflow_pipeline/multicamera_airflow_pipeline/tim_240731/skeletons/sainburg25pt.py")
# n_keypoints = 25
dataset_info_loc = Path("/n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/tim_240731/skeletons/weinreb15pt.py")
n_keypoints = 15

# which config to use (this is what we base the config off of). Should be in the mmpose repo. 
config_loc = Path('/n/groups/datta/tim_sainburg/projects/mmpose/configs/animal_2d_keypoint/rtmpose/ap10k/rtmpose-m_8xb64-210e_ap10k-256x256.py')

# which pretrained model to use (point to .pth file). Pretrained model should be the same model architecture. 
pretrained_model = pretrained_model_directory / "rtmpose-m_simcc-ap10k_pt-aic-coco_210e-256x256-7a041aa1_20230206.pth"
# pretrained_model = '/n/groups/datta/tim_sainburg/projects/24-01-05-multicamera_keypoints_mm2d/models/rtmpose/rtmpose-m_8xb64-210e_ap10k-256x256_24-01-05-13-46-05_748568/best_PCK_epoch_230.pth'
use_pretrained_model = True

# working directory (where model output is saved)
# output_directory = Path("/n/groups/datta/tim_sainburg/datasets/scratch/mm_training")
output_directory = Path("/n/groups/datta/6cam_keypoint_networks/mm_pose/Jonah/20241030_v1")
formatted_datetime = datetime.now().strftime("%y-%m-%d-%H-%M-%S")
working_directory = (output_directory / 'rtmpose' / f"{model_name}_{formatted_datetime}")
working_directory.mkdir(parents=True, exist_ok=True)

# %%
assert config_loc.exists()
assert dataset_directory.exists()

# %% [markdown]
# ### Register the new dataset

# %%
from mmpose.registry import DATASETS
from mmpose.datasets.datasets.base import BaseCocoStyleDataset
dataset_type = 'CoCo15pt'  # must match class name
@DATASETS.register_module()
class CoCo15pt(BaseCocoStyleDataset):
    METAINFO: dict = dict(from_file=dataset_info_loc)

# %% [markdown]
# # You shouldn't need to change anything below here
# (unless you are using a different skeleton model)

# %% [markdown]
# ### Display compute / environment info (for future reference)

# %%
# Check nvcc version
# !nvcc -V
# Check GCC version
# !gcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Mon_Apr__3_17:16:06_PDT_2023
# Cuda compilation tools, release 12.1, V12.1.105
# Build cuda_12.1.r12.1/compiler.32688072_0
# gcc (GCC) 6.2.0
# Copyright (C) 2016 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
from mmengine.utils import get_git_hash
from mmengine.utils.dl_utils import collect_env as collect_base_env
import sys
import mmdet
import torch
import torchvision
import mmpose
from mmcv.ops import get_compiling_cuda_version, get_compiler_version

def collect_env():
    """Collect the information of the running environments."""
    env_info = collect_base_env()
    env_info['MMDetection'] = f'{mmdet.__version__}+{get_git_hash()[:7]}'
    return env_info

print(f"Environment: {sys.executable}")
for name, val in collect_env().items():
    print(f'{name}: {val}')
# Check Pytorch installation
print('cuda version:', get_compiling_cuda_version())
print('compiler information:', get_compiler_version())
print('torch version:', torch.__version__, torch.cuda.is_available())
print('torchvision version:', torchvision.__version__)
print('mmpose version:', mmpose.__version__)
# Out:
# Environment: /n/groups/datta/tim_sainburg/conda_envs/openmmlab/bin/python
# sys.platform: linux
# Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
# CUDA available: True
# numpy_random_seed: 2147483648
# GPU 0: NVIDIA A100 80GB PCIe MIG 3g.40gb
# CUDA_HOME: /n/groups/datta/tim_sainburg/conda_envs/openmmlab
# NVCC: Cuda compilation tools, release 12.1, V12.1.105
# GCC: gcc (GCC) 6.2.0
# PyTorch: 2.1.0
# PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
# TorchVision: 0.16.0
# OpenCV: 4.8.1
# MMEngine: 0.9.1
# MMDetection: 3.3.0+9d18be0
# cuda version: 12.1
# compiler information: GCC 9.3
# torch version: 2.1.0 True
# torchvision version: 0.16.0
# mmpose version: 1.3.1

# %% [markdown]
# ### Create config file

# %%
from mmengine import Config

# %%
cfg = Config.fromfile(config_loc.as_posix())

# %%
# load COCO pre-trained weight
if use_pretrained_model:
    cfg.load_from = pretrained_model.as_posix()

# %%
# set the dataset directory
cfg.data_root = dataset_directory.as_posix()

# set the working directory
cfg.work_dir = working_directory.as_posix()
cfg.randomness = dict(seed=0)

# %%
# set dataset configs
cfg.dataset_type = dataset_type
cfg.data_mode = 'topdown'

# number of keypoints
cfg.model.head.out_channels = n_keypoints

cfg.train_dataloader.dataset.type = cfg.dataset_type
cfg.train_dataloader.dataset.ann_file = 'annotations/instances_train.json'
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix = dict(img='train/')


cfg.val_dataloader.dataset.type = cfg.dataset_type
cfg.val_dataloader.dataset.bbox_file = None
cfg.val_dataloader.dataset.ann_file = 'annotations/instances_val.json'
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix = dict(img='val/')

cfg.test_dataloader.dataset.type = cfg.dataset_type
cfg.test_dataloader.dataset.bbox_file = None
cfg.test_dataloader.dataset.ann_file = 'annotations/instances_val.json'
cfg.test_dataloader.dataset.data_root = cfg.data_root
cfg.test_dataloader.dataset.data_prefix = dict(img='val/')

# set to custom datset
cfg.train_dataloader.dataset.metainfo = dict(from_file=dataset_info_loc.as_posix())
cfg.val_dataloader.dataset.metainfo = dict(from_file=dataset_info_loc.as_posix())
cfg.test_dataloader.dataset.metainfo = dict(from_file=dataset_info_loc.as_posix())

# set evaluator
cfg.val_evaluator = dict(type='PCKAccuracy')
cfg.test_evaluator = cfg.val_evaluator

cfg.default_hooks.checkpoint.save_best = 'PCK'
cfg.default_hooks.checkpoint.max_keep_ckpts = 15
cfg.default_hooks.checkpoint.interval = 10

cfg.max_epochs = 2000
cfg.train_cfg.max_epochs = 2000

# %%
print(cfg)
# Out:
# Config (path: /n/groups/datta/tim_sainburg/projects/mmpose/configs/animal_2d_keypoint/rtmpose/ap10k/rtmpose-m_8xb64-210e_ap10k-256x256.py): {'default_scope': 'mmpose', 'default_hooks': {'timer': {'type': 'IterTimerHook'}, 'logger': {'type': 'LoggerHook', 'interval': 50}, 'param_scheduler': {'type': 'ParamSchedulerHook'}, 'checkpoint': {'type': 'CheckpointHook', 'interval': 10, 'save_best': 'PCK', 'rule': 'greater', 'max_keep_ckpts': 15}, 'sampler_seed': {'type': 'DistSamplerSeedHook'}, 'visualization': {'type': 'PoseVisualizationHook', 'enable': False}, 'badcase': {'type': 'BadCaseAnalysisHook', 'enable': False, 'out_dir': 'badcase', 'metric_type': 'loss', 'badcase_thr': 5}}, 'custom_hooks': [{'type': 'EMAHook', 'ema_type': 'ExpMomentumEMA', 'momentum': 0.0002, 'update_buffers': True, 'priority': 49}, {'type': 'mmdet.PipelineSwitchHook', 'switch_epoch': 180, 'switch_pipeline': [{'type': 'LoadImage', 'backend_args': {'backend': 'local'}}, {'type': 'GetBBoxCenterScale'}, {'type': 'RandomFlip', 'direction': 'horizontal'}, {'type': 'RandomHalfBody'}, {'type': 'RandomBBoxTransform', 'shift_factor': 0.0, 'scale_factor': [0.75, 1.25], 'rotate_factor': 60}, {'type': 'TopdownAffine', 'input_size': (256, 256)}, {'type': 'mmdet.YOLOXHSVRandomAug'}, {'type': 'Albumentation', 'transforms': [{'type': 'Blur', 'p': 0.1}, {'type': 'MedianBlur', 'p': 0.1}, {'type': 'CoarseDropout', 'max_holes': 1, 'max_height': 0.4, 'max_width': 0.4, 'min_holes': 1, 'min_height': 0.2, 'min_width': 0.2, 'p': 0.5}]}, {'type': 'GenerateTarget', 'encoder': {'type': 'SimCCLabel', 'input_size': (256, 256), 'sigma': (5.66, 5.66), 'simcc_split_ratio': 2.0, 'normalize': False, 'use_dark': False}}, {'type': 'PackPoseInputs'}]}], 'env_cfg': {'cudnn_benchmark': False, 'mp_cfg': {'mp_start_method': 'fork', 'opencv_num_threads': 0}, 'dist_cfg': {'backend': 'nccl'}}, 'vis_backends': [{'type': 'LocalVisBackend'}], 'visualizer': {'type': 'PoseLocalVisualizer', 'vis_backends': [{'type': 'LocalVisBackend'}], 'name': 'visualizer'}, 'log_processor': {'type': 'LogProcessor', 'window_size': 50, 'by_epoch': True, 'num_digits': 6}, 'log_level': 'INFO', 'load_from': '/n/groups/datta/tim_sainburg/datasets/scratch/pretrained_mm_models/rtmpose-m_simcc-ap10k_pt-aic-coco_210e-256x256-7a041aa1_20230206.pth', 'resume': False, 'backend_args': {'backend': 'local'}, 'train_cfg': {'by_epoch': True, 'max_epochs': 2000, 'val_interval': 10}, 'val_cfg': {}, 'test_cfg': {}, 'max_epochs': 2000, 'stage2_num_epochs': 30, 'base_lr': 0.004, 'randomness': {'seed': 0}, 'optim_wrapper': {'type': 'OptimWrapper', 'optimizer': {'type': 'AdamW', 'lr': 0.004, 'weight_decay': 0.05}, 'paramwise_cfg': {'norm_decay_mult': 0, 'bias_decay_mult': 0, 'bypass_duplicate': True}}, 'param_scheduler': [{'type': 'LinearLR', 'start_factor': 1e-05, 'by_epoch': False, 'begin': 0, 'end': 1000}, {'type': 'CosineAnnealingLR', 'eta_min': 0.0002, 'begin': 105, 'end': 210, 'T_max': 105, 'by_epoch': True, 'convert_to_iter_based': True}], 'auto_scale_lr': {'base_batch_size': 512}, 'codec': {'type': 'SimCCLabel', 'input_size': (256, 256), 'sigma': (5.66, 5.66), 'simcc_split_ratio': 2.0, 'normalize': False, 'use_dark': False}, 'model': {'type': 'TopdownPoseEstimator', 'data_preprocessor': {'type': 'PoseDataPreprocessor', 'mean': [123.675, 116.28, 103.53], 'std': [58.395, 57.12, 57.375], 'bgr_to_rgb': True}, 'backbone': {'_scope_': 'mmdet', 'type': 'CSPNeXt', 'arch': 'P5', 'expand_ratio': 0.5, 'deepen_factor': 0.67, 'widen_factor': 0.75, 'out_indices': (4,), 'channel_attention': True, 'norm_cfg': {'type': 'SyncBN'}, 'act_cfg': {'type': 'SiLU'}, 'init_cfg': {'type': 'Pretrained', 'prefix': 'backbone.', 'checkpoint': 'https://download.openmmlab.com/mmpose/v1/projects/rtmposev1/cspnext-m_udp-aic-coco_210e-256x192-f2f7d6f6_20230130.pth'}}, 'head': {'type': 'RTMCCHead', 'in_channels': 768, 'out_channels': 15, 'input_size': (256, 256), 'in_featuremap_size': (8, 8), 'simcc_split_ratio': 2.0, 'final_layer_kernel_size': 7, 'gau_cfg': {'hidden_dims': 2 ...

# %%
# set preprocess configs to model
cfg.model.setdefault('data_preprocessor', cfg.get('preprocess_cfg', {}))
# Out:
# {'type': 'PoseDataPreprocessor',
#  'mean': [123.675, 116.28, 103.53],
#  'std': [58.395, 57.12, 57.375],
#  'bgr_to_rgb': True}

# %%
# save configuration file for future reference
cfg.dump(working_directory / 'config.py')

# %% [markdown]
# ### run network

# %%
from mmengine.config import Config, DictAction
from mmengine.runner import Runner

# %%
# build the runner from config
runner = Runner.from_cfg(cfg)
# Out:
# 11/01 20:37:12 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: NVIDIA A100 80GB PCIe MIG 3g.40gb
#     CUDA_HOME: /n/groups/datta/tim_sainburg/conda_envs/openmmlab
#     NVCC: Cuda compilation tools, release 12.1, V12.1.105
#     GCC: gcc (GCC) 6.2.0
#     PyTorch: 2.1.0
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.0
#     OpenCV: 4.8.1
#     MMEngine: 0.9.1
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/01 20:37:14 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=512)
# backend_args = dict(backend='local')
# base_lr = 0.004
# codec = dict(
#     input_size=(
#         256,
#         256,
#     ),
#     normalize=False,
#     sigma=(
#         5.66,
#         5.66,
#     ),
#     simcc_split_ratio=2.0,
#     type='SimCCLabel',
#     use_dark=False)
# custom_hooks = [
#     dict(
#         ema_type='ExpMomentumEMA',
#         momentum=0.0002,
#         priority=49,
#         type='EMAHook',
#         update_buffers=True),
#     dict(
#         switch_epoch=180,
#         switch_pipeline=[
#             dict(backend_args=dict(backend='local'), type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(direction='horizontal', type='RandomFlip'),
#             dict(type='RandomHalfBody'),
#             dict(
#                 rotate_factor=60,
#                 scale_factor=[
#                     0.75,
#                     1.25,
#                 ],
#                 shift_factor=0.0,
#                 type='RandomBBoxTransform'),
#             dict(input_size=(
#                 256,
#                 256,
#             ), type='TopdownAffine'),
#             dict(type='mmdet.YOLOXHSVRandomAug'),
#             dict(
#                 transforms=[
#                     dict(p=0.1, type='Blur'),
#                     dict(p=0.1, type='MedianBlur'),
#                     dict(
#                         max_height=0.4,
#                         max_holes=1,
#                         max_width=0.4,
#                         min_height=0.2,
#                         min_holes=1,
#                         min_width=0.2,
#                         p=0.5,
#                         type='CoarseDropout'),
#                 ],
#                 type='Albumentation'),
#             dict(
#                 encoder=dict(
#                     input_size=(
#                         256,
#                         256,
#                     ),
#                     normalize=False,
#                     sigma=(
#                         5.66,
#                         5.66,
#                     ),
#                     simcc_split_ratio=2.0,
#                     type='SimCCLabel',
#                     use_dark=False),
#                 type='GenerateTarget'),
#             dict(type='PackPoseInputs'),
#         ],
#         type='mmdet.PipelineSwitchHook'),
# ]
# data_mode = 'topdown'
# data_root = '/n/groups/datta/6cam_keypoint_networks/training_data/JP_CW_scale_annos/COCO_format'
# dataset_type = 'CoCo15pt'
# default_hooks = dict(
#     badcase=dict(
#         badcase_thr=5,
#         enable=False,
#         metric_type='loss',
#         out_dir='badcase',
#         type='BadCaseAnalysisHook'),
#     checkpoint=dict(
#         interval=10,
#         max_keep_ckpts=15,
#         rule='greater',
#         save_best='PCK',
#         type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(enable=False, type='PoseVisualizationHook'))
# default_scope = 'mmpose'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# load_from = '/n/groups/datta/tim_sainburg/datasets/scratch/pretrained_mm_models/rtmpose-m_simcc-ap10k_pt-aic-coco_210e-256x256-7a041aa1_20230206.pth'
# log_level = 'INFO'
# log_processor = dict(
#     by_epoch=True, num_digits=6, type='LogProcessor', window_size=50)
# max_epochs = 2000
# model = dict(
#     backbone=dict(
#         _scope_='mmdet',
#         act_cfg=dict(type='SiLU'),
#         arch='P5',
#         channel_attention=True,
#         deepen_factor=0.67,
#         expand_ratio=0.5,
#         init_cfg=dict(
#             checkpoint=
#             'https://download.openmmlab.com/mmpose/v1/projects/rtmposev1/cspnext-m_udp-aic-coco_210e-256x192-f2f7d6f6_20230130.pth',
#             prefix='backbone.',
#             type='Pretrained'),
#         norm_cfg=dict(type='SyncBN'),
#         out_indices=(4, ),
#         type='CSPNeXt',
#         widen_factor=0.75),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='PoseDataPreprocessor'),
#     head=dict(
#         decoder=dict(
#             input_size=(
#                 256,
#                 256,
#             ),
#             normalize=False,
#             sigma=(
#                 5.66,
#                 5.66,
#             ),
#             simcc_split_ratio=2.0,
#             type='SimCCLabel',
#             use_dark=False),
#         final_layer_kernel_size=7,
#         gau_cfg=dict(
#             act_fn='SiLU',
#             drop_path=0.0,
#             dropout_rate=0.0,
#             expansion_factor=2,
#             hidden_dims=256,
#             pos_enc=False,
#             s=128,
#             use_rel_bias=False),
#         in_channels=768,
#         in_featuremap_size=(
#             8,
#             8,
#         ),
#         input_size=(
#             256,
#             256,
#         ),
#         loss=dict(
#             beta=10.0,
#             label_softmax=True,
#             type='KLDiscretLoss',
#             use_target_weight=True),
#         out_channels=15,
#         simcc_split_ratio=2.0,
#         type='RTMCCHead'),
#     test_cfg=dict(flip_test=True),
#     type='TopdownPoseEstimator')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.004, type='AdamW', weight_decay=0.05),
#     paramwise_cfg=dict(
#         bias_decay_mult=0, bypass_duplicate=True, norm_decay_mult=0),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1000, start_factor=1e-05,
#         type='LinearLR'),
#     dict(
#         T_max=105,
#         begin=105,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         end=210,
#         eta_min=0.0002,
#         type='CosineAnnealingLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# stage2_num_epochs = 30
# test_cfg = dict()
# test_dataloader = dict(
#     batch_size=32,
#     dataset=dict(
#         ann_file='annotations/instances_val.json',
#         bbox_file=None,
#         data_mode='topdown',
#         data_prefix=dict(img='val/'),
#         data_root=
#         '/n/groups/datta/6cam_keypoint_networks/training_data/JP_CW_scale_annos/COCO_format',
#         metainfo=dict(
#             from_file=
#             '/n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/tim_240731/skeletons/weinreb15pt.py'
#         ),
#         pipeline=[
#             dict(backend_args=dict(backend='local'), type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(input_size=(
#                 256,
#                 256,
#             ), type='TopdownAffine'),
#             dict(type='PackPoseInputs'),
#         ],
#         test_mode=True,
#         type='CoCo15pt'),
#     drop_last=False,
#     num_workers=10,
#     persistent_workers=True,
#     sampler=dict(round_up=False, shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(type='PCKAccuracy')
# train_cfg = dict(by_epoch=True, max_epochs=2000, val_interval=10)
# train_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='annotations/instances_train.json',
#         data_mode='topdown',
#         data_prefix=dict(img='train/'),
#         data_root=
#         '/n/groups/datta/6cam_keypoint_networks/training_data/JP_CW_scale_annos/COCO_format',
#         metainfo=dict(
#             from_file=
#             '/n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/tim_240731/skeletons/weinreb15pt.py'
#         ),
#         pipeline=[
#             dict(backend_args=dict(backend='local'), type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(direction='horizontal', type='RandomFlip'),
#             dict(type='RandomHalfBody'),
#             dict(
#                 rotate_factor=80,
#                 scale_factor=[
#                     0.6,
#                     1.4,
#                 ],
#                 type='RandomBBoxTransform'),
#             dict(input_size=(
#                 256,
#                 256,
#             ), type='TopdownAffine'),
#             dict(type='mmdet.YOLOXHSVRandomAug'),
#             dict(
#                 transforms=[
#                     dict(p=0.1, type='Blur'),
#                     dict(p=0.1, type='MedianBlur'),
#                     dict(
#                         max_height=0.4,
#                         max_holes=1,
#                         max_width=0.4,
#                         min_height=0.2,
#                         min_holes=1,
#                         min_width=0.2,
#                         p=1.0,
#                         type='CoarseDropout'),
#                 ],
#                 type='Albumentation'),
#             dict(
#                 encoder=dict(
#                     input_size=(
#                         256,
#                         256,
#                     ),
#                     normalize=False,
#                     sigma=(
#                         5.66,
#                         5.66,
#                     ),
#                     simcc_split_ratio=2.0,
#                     type='SimCCLabel',
#                     use_dark=False),
#                 type='GenerateTarget'),
#             dict(type='PackPoseInputs'),
#         ],
#         type='CoCo15pt'),
#     num_workers=10,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=dict(backend='local'), type='LoadImage'),
#     dict(type='GetBBoxCenterScale'),
#     dict(direction='horizontal', type='RandomFlip'),
#     dict(type='RandomHalfBody'),
#     dict(
#         rotate_factor=80,
#         scale_factor=[
#             0.6,
#             1.4,
#         ],
#         type='RandomBBoxTransform'),
#     dict(input_size=(
#         256,
#         256,
#     ), type='TopdownAffine'),
#     dict(type='mmdet.YOLOXHSVRandomAug'),
#     dict(
#         transforms=[
#             dict(p=0.1, type='Blur'),
#             dict(p=0.1, type='MedianBlur'),
#             dict(
#                 max_height=0.4,
#                 max_holes=1,
#                 max_width=0.4,
#                 min_height=0.2,
#                 min_holes=1,
#                 min_width=0.2,
#                 p=1.0,
#                 type='CoarseDropout'),
#         ],
#         type='Albumentation'),
#     dict(
#         encoder=dict(
#             input_size=(
#                 256,
#                 256,
#             ),
#             normalize=False,
#             sigma=(
#                 5.66,
#                 5.66,
#             ),
#             simcc_split_ratio=2.0,
#             type='SimCCLabel',
#             use_dark=False),
#         type='GenerateTarget'),
#     dict(type='PackPoseInputs'),
# ]
# train_pipeline_stage2 = [
#     dict(backend_args=dict(backend='local'), type='LoadImage'),
#     dict(type='GetBBoxCenterScale'),
#     dict(direction='horizontal', type='RandomFlip'),
#     dict(type='RandomHalfBody'),
#     dict(
#         rotate_factor=60,
#         scale_factor=[
#             0.75,
#             1.25,
#         ],
#         shift_factor=0.0,
#         type='RandomBBoxTransform'),
#     dict(input_size=(
#         256,
#         256,
#     ), type='TopdownAffine'),
#     dict(type='mmdet.YOLOXHSVRandomAug'),
#     dict(
#         transforms=[
#             dict(p=0.1, type='Blur'),
#             dict(p=0.1, type='MedianBlur'),
#             dict(
#                 max_height=0.4,
#                 max_holes=1,
#                 max_width=0.4,
#                 min_height=0.2,
#                 min_holes=1,
#                 min_width=0.2,
#                 p=0.5,
#                 type='CoarseDropout'),
#         ],
#         type='Albumentation'),
#     dict(
#         encoder=dict(
#             input_size=(
#                 256,
#                 256,
#             ),
#             normalize=False,
#             sigma=(
#                 5.66,
#                 5.66,
#             ),
#             simcc_split_ratio=2.0,
#             type='SimCCLabel',
#             use_dark=False),
#         type='GenerateTarget'),
#     dict(type='PackPoseInputs'),
# ]
# val_cfg = dict()
# val_dataloader = dict(
#     batch_size=32,
#     dataset=dict(
#         ann_file='annotations/instances_val.json',
#         bbox_file=None,
#         data_mode='topdown',
#         data_prefix=dict(img='val/'),
#         data_root=
#         '/n/groups/datta/6cam_keypoint_networks/training_data/JP_CW_scale_annos/COCO_format',
#         metainfo=dict(
#             from_file=
#             '/n/groups/datta/Jonah/Local_code_groups/6cam_repos/multicam_airflow_pipeline/multicamera_airflow_pipeline/tim_240731/skeletons/weinreb15pt.py'
#         ),
#         pipeline=[
#             dict(backend_args=dict(backend='local'), type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(input_size=(
#                 256,
#                 256,
#             ), type='TopdownAffine'),
#             dict(type='PackPoseInputs'),
#         ],
#         test_mode=True,
#         type='CoCo15pt'),
#     drop_last=False,
#     num_workers=10,
#     persistent_workers=True,
#     sampler=dict(round_up=False, shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(type='PCKAccuracy')
# val_pipeline = [
#     dict(backend_args=dict(backend='local'), type='LoadImage'),
#     dict(type='GetBBoxCenterScale'),
#     dict(input_size=(
#         256,
#         256,
#     ), type='TopdownAffine'),
#     dict(type='PackPoseInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='PoseLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = '/n/groups/datta/6cam_keypoint_networks/mm_pose/Jonah/20241030_v1/rtmpose/rtmpose-m_8xb64-210e_ap10k-256x256_24-11-01-20-36-55'
#
# 11/01 20:37:17 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/01 20:37:17 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_load_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (NORMAL      ) PipelineSwitchHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) PoseVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_save_checkpoint:
# (49          ) EMAHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) PoseVisualizationHook
# (NORMAL      ) BadCaseAnalysisHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) BadCaseAnalysisHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------

# %%
# start training
runner.train()
# Out:
# /n/groups/datta/tim_sainburg/conda_envs/openmmlab/lib/python3.10/site-packages/mmpose/datasets/transforms/common_transforms.py:656: UserWarning: Blur is not pixel-level transformations. Please use with caution.
#   warnings.warn(
# /n/groups/datta/tim_sainburg/conda_envs/openmmlab/lib/python3.10/site-packages/mmpose/datasets/transforms/common_transforms.py:656: UserWarning: MedianBlur is not pixel-level transformations. Please use with caution.
#   warnings.warn(
# /n/groups/datta/tim_sainburg/conda_envs/openmmlab/lib/python3.10/site-packages/mmpose/datasets/transforms/common_transforms.py:656: UserWarning: CoarseDropout is not pixel-level transformations. Please use with caution.
#   warnings.warn(
# loading annotations into memory...
# Done (t=0.12s)
# creating index...
# index created!
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stem.0.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stem.0.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stem.1.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stem.1.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stem.2.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stem.2.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.0.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.0.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.main_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.main_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.short_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.short_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.final_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.final_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage1.1.attention.fc.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.0.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.0.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.main_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.main_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.short_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.short_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.final_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.final_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:20 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage2.1.attention.fc.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.0.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.0.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.main_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.main_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.short_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.short_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.final_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.final_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage3.1.attention.fc.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.0.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.0.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv2.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv2.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.main_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.main_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.short_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.short_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.final_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.final_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv1.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv1.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- backbone.stage4.2.attention.fc.bias:weight_decay=0.0
# 11/01 20:37:21 - mmengine - INFO - paramwise_options -- head.final_layer.bias:weight_decay=0.0
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 11/01 20:37:21 - mmengine - WARNING - The prefix is not set in metric class PCKAccuracy.
# 11/01 20:37:22 - mmengine - INFO - load backbone. in model from: https://download.openmmlab.com/mmpose/v1/projects/rtmposev1/cspnext-m_udp-aic-coco_210e-256x192-f2f7d6f6_20230130.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmpose/v1/projects/rtmposev1/cspnext-m_udp-aic-coco_210e-256x192-f2f7d6f6_20230130.pth
# Loads checkpoint by local backend from path: /n/groups/datta/tim_sainburg/datasets/scratch/pretrained_mm_models/rtmpose-m_simcc-ap10k_pt-aic-coco_210e-256x256-7a041aa1_20230206.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for head.final_layer.weight: copying a param with shape torch.Size([17, 768, 7, 7]) from checkpoint, the shape in current model is torch.Size([15, 768, 7, 7]).
# size mismatch for head.final_layer.bias: copying a param with shape torch.Size([17]) from checkpoint, the shape in current model is torch.Size([15]).
# The model and loaded state dict do not match exactly
#
# size mismatch for head.final_layer.weight: copying a param with shape torch.Size([17, 768, 7, 7]) from checkpoint, the shape in current model is torch.Size([15, 768, 7, 7]).
# size mismatch for head.final_layer.bias: copying a param with shape torch.Size([17]) from checkpoint, the shape in current model is torch.Size([15]).
# 11/01 20:37:23 - mmengine - INFO - Load checkpoint from /n/groups/datta/tim_sainburg/datasets/scratch/pretrained_mm_models/rtmpose-m_simcc-ap10k_pt-aic-coco_210e-256x256-7a041aa1_20230206.pth
# 11/01 20:37:23 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 11/01 20:37:23 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 11/01 20:37:23 - mmengine - INFO - Checkpoints will be saved to /n/groups/datta/6cam_keypoint_networks/mm_pose/Jonah/20241030_v1/rtmpose/rtmpose-m_8xb64-210e_ap10k-256x256_24-11-01-20-36-55.
# 11/01 20:37:41 - mmengine - INFO - Epoch(train)    [1][ 50/241]  base_lr: 1.962342e-04 lr: 1.962342e-04  eta: 2 days, 1:02:46  time: 0.366359  data_time: 0.129983  memory: 5730  loss: 4.353880  loss_kpt: 4.353880  acc_pose: 0.011546
# 11/01 20:37:56 - mmengine - INFO - Epoch(train)    [1][100/241]  base_lr: 3.964324e-04 lr: 3.964324e-04  eta: 1 day, 21:16:29  time: 0.310085  data_time: 0.097851  memory: 5730  loss: 0.643339  loss_kpt: 0.643339  acc_pose: 0.036481
# 11/01 20:38:12 - mmengine - INFO - Epoch(train)    [1][150/241]  base_lr: 5.966306e-04 lr: 5.966306e-04  eta: 1 day, 20:22:20  time: 0.318103  data_time: 0.113564  memory: 5730  loss: 0.616151  loss_kpt: 0.616151  acc_pose: 0.041642
# 11/01 20:38:27 - mmengine - INFO - Epoch(train)    [1][200/241]  base_lr: 7.968288e-04 lr: 7.968288e-04  eta: 1 day, 18:58:08  time: 0.289711  data_time: 0.087849  memory: 5730  loss: 0.607510  loss_kpt: 0.607510  acc_pose: 0.057230
# 11/01 20:38:38 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:38:55 - mmengine - INFO - Epoch(train)    [2][ 50/241]  base_lr: 1.161190e-03 lr: 1.161190e-03  eta: 1 day, 18:26:41  time: 0.332941  data_time: 0.121509  memory: 5730  loss: 0.589658  loss_kpt: 0.589658  acc_pose: 0.092812
# 11/01 20:39:10 - mmengine - INFO - Epoch(train)    [2][100/241]  base_lr: 1.361388e-03 lr: 1.361388e-03  eta: 1 day, 17:59:58  time: 0.294735  data_time: 0.084298  memory: 5730  loss: 0.572108  loss_kpt: 0.572108  acc_pose: 0.089610
# 11/01 20:39:24 - mmengine - INFO - Epoch(train)    [2][150/241]  base_lr: 1.561586e-03 lr: 1.561586e-03  eta: 1 day, 17:36:52  time: 0.291658  data_time: 0.082788  memory: 5730  loss: 0.558104  loss_kpt: 0.558104  acc_pose: 0.109716
# 11/01 20:39:39 - mmengine - INFO - Epoch(train)    [2][200/241]  base_lr: 1.761784e-03 lr: 1.761784e-03  eta: 1 day, 17:15:49  time: 0.288218  data_time: 0.081329  memory: 5730  loss: 0.543092  loss_kpt: 0.543092  acc_pose: 0.178034
# 11/01 20:39:50 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:40:07 - mmengine - INFO - Epoch(train)    [3][ 50/241]  base_lr: 2.126145e-03 lr: 2.126145e-03  eta: 1 day, 17:11:27  time: 0.328725  data_time: 0.108646  memory: 5730  loss: 0.522198  loss_kpt: 0.522198  acc_pose: 0.257480
# 11/01 20:40:21 - mmengine - INFO - Epoch(train)    [3][100/241]  base_lr: 2.326343e-03 lr: 2.326343e-03  eta: 1 day, 16:59:24  time: 0.290880  data_time: 0.083176  memory: 5730  loss: 0.507743  loss_kpt: 0.507743  acc_pose: 0.235317
# 11/01 20:40:36 - mmengine - INFO - Epoch(train)    [3][150/241]  base_lr: 2.526541e-03 lr: 2.526541e-03  eta: 1 day, 16:49:08  time: 0.290758  data_time: 0.079903  memory: 5730  loss: 0.490179  loss_kpt: 0.490179  acc_pose: 0.264992
# 11/01 20:40:50 - mmengine - INFO - Epoch(train)    [3][200/241]  base_lr: 2.726739e-03 lr: 2.726739e-03  eta: 1 day, 16:43:12  time: 0.295608  data_time: 0.078703  memory: 5730  loss: 0.476383  loss_kpt: 0.476383  acc_pose: 0.317951
# 11/01 20:41:02 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:41:19 - mmengine - INFO - Epoch(train)    [4][ 50/241]  base_lr: 3.091100e-03 lr: 3.091100e-03  eta: 1 day, 16:47:36  time: 0.334625  data_time: 0.117968  memory: 5730  loss: 0.459957  loss_kpt: 0.459957  acc_pose: 0.431138
# 11/01 20:41:33 - mmengine - INFO - Epoch(train)    [4][100/241]  base_lr: 3.291298e-03 lr: 3.291298e-03  eta: 1 day, 16:41:30  time: 0.293159  data_time: 0.082932  memory: 5730  loss: 0.447304  loss_kpt: 0.447304  acc_pose: 0.411379
# 11/01 20:41:48 - mmengine - INFO - Epoch(train)    [4][150/241]  base_lr: 3.491497e-03 lr: 3.491497e-03  eta: 1 day, 16:39:20  time: 0.300288  data_time: 0.092728  memory: 5730  loss: 0.436400  loss_kpt: 0.436400  acc_pose: 0.433062
# 11/01 20:42:03 - mmengine - INFO - Epoch(train)    [4][200/241]  base_lr: 3.691695e-03 lr: 3.691695e-03  eta: 1 day, 16:38:56  time: 0.303871  data_time: 0.091205  memory: 5730  loss: 0.424274  loss_kpt: 0.424274  acc_pose: 0.491611
# 11/01 20:42:15 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:42:27 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:42:31 - mmengine - INFO - Epoch(train)    [5][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:36:46  time: 0.324777  data_time: 0.110663  memory: 5730  loss: 0.406141  loss_kpt: 0.406141  acc_pose: 0.583319
# 11/01 20:42:46 - mmengine - INFO - Epoch(train)    [5][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:32:55  time: 0.294404  data_time: 0.078087  memory: 5730  loss: 0.397232  loss_kpt: 0.397232  acc_pose: 0.527483
# 11/01 20:43:00 - mmengine - INFO - Epoch(train)    [5][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:27:08  time: 0.288149  data_time: 0.079341  memory: 5730  loss: 0.390525  loss_kpt: 0.390525  acc_pose: 0.583223
# 11/01 20:43:15 - mmengine - INFO - Epoch(train)    [5][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:22:06  time: 0.288976  data_time: 0.076621  memory: 5730  loss: 0.388826  loss_kpt: 0.388826  acc_pose: 0.505800
# 11/01 20:43:26 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:43:42 - mmengine - INFO - Epoch(train)    [6][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:22:33  time: 0.329527  data_time: 0.110842  memory: 5730  loss: 0.373591  loss_kpt: 0.373591  acc_pose: 0.623759
# 11/01 20:43:57 - mmengine - INFO - Epoch(train)    [6][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:18:13  time: 0.289093  data_time: 0.071792  memory: 5730  loss: 0.367929  loss_kpt: 0.367929  acc_pose: 0.628655
# 11/01 20:44:11 - mmengine - INFO - Epoch(train)    [6][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:15:08  time: 0.292226  data_time: 0.078932  memory: 5730  loss: 0.365712  loss_kpt: 0.365712  acc_pose: 0.653051
# 11/01 20:44:26 - mmengine - INFO - Epoch(train)    [6][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:12:21  time: 0.292641  data_time: 0.078526  memory: 5730  loss: 0.365041  loss_kpt: 0.365041  acc_pose: 0.711523
# 11/01 20:44:37 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:44:53 - mmengine - INFO - Epoch(train)    [7][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:11:13  time: 0.321421  data_time: 0.104259  memory: 5730  loss: 0.355955  loss_kpt: 0.355955  acc_pose: 0.666344
# 11/01 20:45:08 - mmengine - INFO - Epoch(train)    [7][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:09:36  time: 0.295765  data_time: 0.082817  memory: 5730  loss: 0.353370  loss_kpt: 0.353370  acc_pose: 0.628785
# 11/01 20:45:23 - mmengine - INFO - Epoch(train)    [7][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:07:45  time: 0.294577  data_time: 0.074701  memory: 5730  loss: 0.349497  loss_kpt: 0.349497  acc_pose: 0.708105
# 11/01 20:45:37 - mmengine - INFO - Epoch(train)    [7][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:06:01  time: 0.294615  data_time: 0.075642  memory: 5730  loss: 0.344644  loss_kpt: 0.344644  acc_pose: 0.713339
# 11/01 20:45:49 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:46:05 - mmengine - INFO - Epoch(train)    [8][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:06:11  time: 0.323685  data_time: 0.104362  memory: 5730  loss: 0.342239  loss_kpt: 0.342239  acc_pose: 0.675914
# 11/01 20:46:19 - mmengine - INFO - Epoch(train)    [8][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:03:05  time: 0.287889  data_time: 0.073072  memory: 5730  loss: 0.339315  loss_kpt: 0.339315  acc_pose: 0.648780
# 11/01 20:46:34 - mmengine - INFO - Epoch(train)    [8][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:02:00  time: 0.296489  data_time: 0.082037  memory: 5730  loss: 0.334793  loss_kpt: 0.334793  acc_pose: 0.710760
# 11/01 20:46:49 - mmengine - INFO - Epoch(train)    [8][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:00:06  time: 0.292307  data_time: 0.082658  memory: 5730  loss: 0.330956  loss_kpt: 0.330956  acc_pose: 0.755761
# 11/01 20:47:00 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:47:16 - mmengine - INFO - Epoch(train)    [9][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:00:31  time: 0.324854  data_time: 0.111793  memory: 5730  loss: 0.328765  loss_kpt: 0.328765  acc_pose: 0.720007
# 11/01 20:47:23 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:47:31 - mmengine - INFO - Epoch(train)    [9][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:58:49  time: 0.292767  data_time: 0.080411  memory: 5730  loss: 0.328126  loss_kpt: 0.328126  acc_pose: 0.700602
# 11/01 20:47:46 - mmengine - INFO - Epoch(train)    [9][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:58:20  time: 0.298611  data_time: 0.084583  memory: 5730  loss: 0.324177  loss_kpt: 0.324177  acc_pose: 0.691912
# 11/01 20:48:01 - mmengine - INFO - Epoch(train)    [9][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:58:17  time: 0.300943  data_time: 0.088124  memory: 5730  loss: 0.321782  loss_kpt: 0.321782  acc_pose: 0.753508
# 11/01 20:48:12 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:48:29 - mmengine - INFO - Epoch(train)   [10][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:00:19  time: 0.333893  data_time: 0.118336  memory: 5730  loss: 0.321671  loss_kpt: 0.321671  acc_pose: 0.680443
# 11/01 20:48:44 - mmengine - INFO - Epoch(train)   [10][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:59:44  time: 0.298250  data_time: 0.081087  memory: 5730  loss: 0.318148  loss_kpt: 0.318148  acc_pose: 0.757479
# 11/01 20:48:59 - mmengine - INFO - Epoch(train)   [10][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:59:16  time: 0.298917  data_time: 0.090224  memory: 5730  loss: 0.314015  loss_kpt: 0.314015  acc_pose: 0.733641
# 11/01 20:49:14 - mmengine - INFO - Epoch(train)   [10][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:58:10  time: 0.295074  data_time: 0.084858  memory: 5730  loss: 0.314555  loss_kpt: 0.314555  acc_pose: 0.773278
# 11/01 20:49:25 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:49:25 - mmengine - INFO - Saving checkpoint at 10 epochs
# 11/01 20:49:34 - mmengine - INFO - Epoch(val)   [10][50/54]    eta: 0:00:00  time: 0.140165  data_time: 0.064200  memory: 5730
# 11/01 20:49:34 - mmengine - INFO - Evaluating PCKAccuracy (normalized by ``"bbox_size"``)...
# 11/01 20:49:34 - mmengine - INFO - Epoch(val) [10][54/54]    PCK: 0.858906  data_time: 0.059808  time: 0.134739
# 11/01 20:49:36 - mmengine - INFO - The best checkpoint with 0.8589 PCK at 10 epoch is saved to best_PCK_epoch_10.pth.
# 11/01 20:49:56 - mmengine - INFO - Epoch(train)   [11][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:00:52  time: 0.341731  data_time: 0.125342  memory: 5730  loss: 0.312879  loss_kpt: 0.312879  acc_pose: 0.758010
# 11/01 20:50:11 - mmengine - INFO - Epoch(train)   [11][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:00:11  time: 0.297719  data_time: 0.080678  memory: 5730  loss: 0.311096  loss_kpt: 0.311096  acc_pose: 0.704986
# 11/01 20:50:26 - mmengine - INFO - Epoch(train)   [11][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:00:14  time: 0.302196  data_time: 0.090957  memory: 5730  loss: 0.311538  loss_kpt: 0.311538  acc_pose: 0.695006
# 11/01 20:50:41 - mmengine - INFO - Epoch(train)   [11][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:59:39  time: 0.298202  data_time: 0.075800  memory: 5730  loss: 0.310027  loss_kpt: 0.310027  acc_pose: 0.710821
# 11/01 20:50:52 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:51:09 - mmengine - INFO - Epoch(train)   [12][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 16:00:22  time: 0.328759  data_time: 0.121790  memory: 5730  loss: 0.304694  loss_kpt: 0.304694  acc_pose: 0.780596
# 11/01 20:51:23 - mmengine - INFO - Epoch(train)   [12][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:58:13  time: 0.287408  data_time: 0.078881  memory: 5730  loss: 0.308652  loss_kpt: 0.308652  acc_pose: 0.747708
# 11/01 20:51:38 - mmengine - INFO - Epoch(train)   [12][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:57:10  time: 0.294566  data_time: 0.085350  memory: 5730  loss: 0.305432  loss_kpt: 0.305432  acc_pose: 0.783481
# 11/01 20:51:52 - mmengine - INFO - Epoch(train)   [12][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:55:26  time: 0.289613  data_time: 0.082684  memory: 5730  loss: 0.303124  loss_kpt: 0.303124  acc_pose: 0.763787
# 11/01 20:52:04 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:52:21 - mmengine - INFO - Epoch(train)   [13][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:57:37  time: 0.338280  data_time: 0.123214  memory: 5730  loss: 0.301507  loss_kpt: 0.301507  acc_pose: 0.837791
# 11/01 20:52:35 - mmengine - INFO - Epoch(train)   [13][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:56:51  time: 0.296538  data_time: 0.083771  memory: 5730  loss: 0.301867  loss_kpt: 0.301867  acc_pose: 0.788849
# 11/01 20:52:38 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:52:50 - mmengine - INFO - Epoch(train)   [13][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:55:51  time: 0.294482  data_time: 0.082352  memory: 5730  loss: 0.297837  loss_kpt: 0.297837  acc_pose: 0.811910
# 11/01 20:53:05 - mmengine - INFO - Epoch(train)   [13][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:55:01  time: 0.295579  data_time: 0.088249  memory: 5730  loss: 0.298546  loss_kpt: 0.298546  acc_pose: 0.812356
# 11/01 20:53:16 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:53:32 - mmengine - INFO - Epoch(train)   [14][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:54:51  time: 0.321035  data_time: 0.105580  memory: 5730  loss: 0.297482  loss_kpt: 0.297482  acc_pose: 0.714423
# 11/01 20:53:48 - mmengine - INFO - Epoch(train)   [14][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:56:48  time: 0.317908  data_time: 0.104159  memory: 5730  loss: 0.297703  loss_kpt: 0.297703  acc_pose: 0.745335
# 11/01 20:54:03 - mmengine - INFO - Epoch(train)   [14][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:56:24  time: 0.299042  data_time: 0.084689  memory: 5730  loss: 0.295791  loss_kpt: 0.295791  acc_pose: 0.817289
# 11/01 20:54:18 - mmengine - INFO - Epoch(train)   [14][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:55:14  time: 0.292706  data_time: 0.087622  memory: 5730  loss: 0.293343  loss_kpt: 0.293343  acc_pose: 0.788670
# 11/01 20:54:29 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:54:45 - mmengine - INFO - Epoch(train)   [15][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:53:55  time: 0.319340  data_time: 0.110804  memory: 5730  loss: 0.291809  loss_kpt: 0.291809  acc_pose: 0.758508
# 11/01 20:55:00 - mmengine - INFO - Epoch(train)   [15][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:52:59  time: 0.294142  data_time: 0.079415  memory: 5730  loss: 0.293283  loss_kpt: 0.293283  acc_pose: 0.800746
# 11/01 20:55:14 - mmengine - INFO - Epoch(train)   [15][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:50  time: 0.292227  data_time: 0.079993  memory: 5730  loss: 0.295505  loss_kpt: 0.295505  acc_pose: 0.788138
# 11/01 20:55:29 - mmengine - INFO - Epoch(train)   [15][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:50:57  time: 0.294146  data_time: 0.083274  memory: 5730  loss: 0.293120  loss_kpt: 0.293120  acc_pose: 0.801174
# 11/01 20:55:40 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:55:57 - mmengine - INFO - Epoch(train)   [16][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:55  time: 0.332800  data_time: 0.115591  memory: 5730  loss: 0.291276  loss_kpt: 0.291276  acc_pose: 0.802675
# 11/01 20:56:12 - mmengine - INFO - Epoch(train)   [16][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:20  time: 0.296900  data_time: 0.079356  memory: 5730  loss: 0.291825  loss_kpt: 0.291825  acc_pose: 0.829462
# 11/01 20:56:27 - mmengine - INFO - Epoch(train)   [16][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:50  time: 0.307034  data_time: 0.097398  memory: 5730  loss: 0.286229  loss_kpt: 0.286229  acc_pose: 0.771208
# 11/01 20:56:42 - mmengine - INFO - Epoch(train)   [16][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:58  time: 0.303810  data_time: 0.091025  memory: 5730  loss: 0.290867  loss_kpt: 0.290867  acc_pose: 0.797970
# 11/01 20:56:54 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:57:10 - mmengine - INFO - Epoch(train)   [17][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:53:03  time: 0.334500  data_time: 0.117084  memory: 5730  loss: 0.288371  loss_kpt: 0.288371  acc_pose: 0.814804
# 11/01 20:57:25 - mmengine - INFO - Epoch(train)   [17][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:49  time: 0.290668  data_time: 0.077000  memory: 5730  loss: 0.289875  loss_kpt: 0.289875  acc_pose: 0.808046
# 11/01 20:57:38 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:57:40 - mmengine - INFO - Epoch(train)   [17][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:52:08  time: 0.305936  data_time: 0.092611  memory: 5730  loss: 0.287929  loss_kpt: 0.287929  acc_pose: 0.815226
# 11/01 20:57:55 - mmengine - INFO - Epoch(train)   [17][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:52  time: 0.300026  data_time: 0.090806  memory: 5730  loss: 0.289106  loss_kpt: 0.289106  acc_pose: 0.775090
# 11/01 20:58:06 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:58:23 - mmengine - INFO - Epoch(train)   [18][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:52:48  time: 0.342549  data_time: 0.134356  memory: 5730  loss: 0.285521  loss_kpt: 0.285521  acc_pose: 0.823584
# 11/01 20:58:38 - mmengine - INFO - Epoch(train)   [18][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:52:20  time: 0.298130  data_time: 0.093012  memory: 5730  loss: 0.289175  loss_kpt: 0.289175  acc_pose: 0.819368
# 11/01 20:58:53 - mmengine - INFO - Epoch(train)   [18][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:52:34  time: 0.305600  data_time: 0.095093  memory: 5730  loss: 0.284604  loss_kpt: 0.284604  acc_pose: 0.790398
# 11/01 20:59:08 - mmengine - INFO - Epoch(train)   [18][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:52:12  time: 0.299186  data_time: 0.084151  memory: 5730  loss: 0.287421  loss_kpt: 0.287421  acc_pose: 0.840930
# 11/01 20:59:20 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 20:59:37 - mmengine - INFO - Epoch(train)   [19][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:53:57  time: 0.339795  data_time: 0.119397  memory: 5730  loss: 0.287295  loss_kpt: 0.287295  acc_pose: 0.810280
# 11/01 20:59:52 - mmengine - INFO - Epoch(train)   [19][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:53:10  time: 0.294837  data_time: 0.077537  memory: 5730  loss: 0.286171  loss_kpt: 0.286171  acc_pose: 0.770086
# 11/01 21:00:07 - mmengine - INFO - Epoch(train)   [19][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:52:50  time: 0.299766  data_time: 0.085168  memory: 5730  loss: 0.287049  loss_kpt: 0.287049  acc_pose: 0.788642
# 11/01 21:00:22 - mmengine - INFO - Epoch(train)   [19][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:52:04  time: 0.294720  data_time: 0.080046  memory: 5730  loss: 0.286991  loss_kpt: 0.286991  acc_pose: 0.809816
# 11/01 21:00:33 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 21:00:49 - mmengine - INFO - Epoch(train)   [20][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:52:22  time: 0.333531  data_time: 0.110662  memory: 5730  loss: 0.287953  loss_kpt: 0.287953  acc_pose: 0.827733
# 11/01 21:01:04 - mmengine - INFO - Epoch(train)   [20][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:12  time: 0.289887  data_time: 0.081015  memory: 5730  loss: 0.286735  loss_kpt: 0.286735  acc_pose: 0.846253
# 11/01 21:01:19 - mmengine - INFO - Epoch(train)   [20][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:20  time: 0.305244  data_time: 0.091318  memory: 5730  loss: 0.289458  loss_kpt: 0.289458  acc_pose: 0.824676
# 11/01 21:01:34 - mmengine - INFO - Epoch(train)   [20][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:50:16  time: 0.290728  data_time: 0.076334  memory: 5730  loss: 0.286089  loss_kpt: 0.286089  acc_pose: 0.745292
# 11/01 21:01:46 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 21:01:46 - mmengine - INFO - Saving checkpoint at 20 epochs
# 11/01 21:01:54 - mmengine - INFO - Epoch(val)   [20][50/54]    eta: 0:00:00  time: 0.123036  data_time: 0.053630  memory: 5730
# 11/01 21:01:55 - mmengine - INFO - Evaluating PCKAccuracy (normalized by ``"bbox_size"``)...
# 11/01 21:01:55 - mmengine - INFO - Epoch(val) [20][54/54]    PCK: 0.897501  data_time: 0.049076  time: 0.117132
# 11/01 21:01:55 - mmengine - INFO - The previous best checkpoint /n/groups/datta/6cam_keypoint_networks/mm_pose/Jonah/20241030_v1/rtmpose/rtmpose-m_8xb64-210e_ap10k-256x256_24-11-01-20-36-55/best_PCK_epoch_10.pth is removed
# 11/01 21:01:57 - mmengine - INFO - The best checkpoint with 0.8975 PCK at 20 epoch is saved to best_PCK_epoch_20.pth.
# 11/01 21:02:16 - mmengine - INFO - Epoch(train)   [21][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:52  time: 0.327375  data_time: 0.106391  memory: 5730  loss: 0.286027  loss_kpt: 0.286027  acc_pose: 0.810700
# 11/01 21:02:31 - mmengine - INFO - Epoch(train)   [21][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:58  time: 0.305187  data_time: 0.087483  memory: 5730  loss: 0.288308  loss_kpt: 0.288308  acc_pose: 0.806415
# 11/01 21:02:46 - mmengine - INFO - Epoch(train)   [21][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:19  time: 0.295796  data_time: 0.081168  memory: 5730  loss: 0.285340  loss_kpt: 0.285340  acc_pose: 0.797659
# 11/01 21:02:55 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 21:03:01 - mmengine - INFO - Epoch(train)   [21][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:50:45  time: 0.296736  data_time: 0.078870  memory: 5730  loss: 0.285780  loss_kpt: 0.285780  acc_pose: 0.800575
# 11/01 21:03:12 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 21:03:29 - mmengine - INFO - Epoch(train)   [22][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:51:42  time: 0.336522  data_time: 0.112040  memory: 5730  loss: 0.287781  loss_kpt: 0.287781  acc_pose: 0.800751
# 11/01 21:03:43 - mmengine - INFO - Epoch(train)   [22][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:50:19  time: 0.286157  data_time: 0.074043  memory: 5730  loss: 0.291149  loss_kpt: 0.291149  acc_pose: 0.809878
# 11/01 21:03:58 - mmengine - INFO - Epoch(train)   [22][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:49:29  time: 0.293303  data_time: 0.083219  memory: 5730  loss: 0.286781  loss_kpt: 0.286781  acc_pose: 0.813015
# 11/01 21:04:13 - mmengine - INFO - Epoch(train)   [22][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:48:51  time: 0.295577  data_time: 0.086822  memory: 5730  loss: 0.286529  loss_kpt: 0.286529  acc_pose: 0.863399
# 11/01 21:04:24 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 21:04:41 - mmengine - INFO - Epoch(train)   [23][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:49:14  time: 0.329979  data_time: 0.113794  memory: 5730  loss: 0.288838  loss_kpt: 0.288838  acc_pose: 0.782317
# 11/01 21:04:55 - mmengine - INFO - Epoch(train)   [23][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:48:33  time: 0.294821  data_time: 0.075905  memory: 5730  loss: 0.287694  loss_kpt: 0.287694  acc_pose: 0.795760
# 11/01 21:05:10 - mmengine - INFO - Epoch(train)   [23][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:48:11  time: 0.299077  data_time: 0.079749  memory: 5730  loss: 0.290880  loss_kpt: 0.290880  acc_pose: 0.842624
# 11/01 21:05:25 - mmengine - INFO - Epoch(train)   [23][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:47:20  time: 0.292380  data_time: 0.084344  memory: 5730  loss: 0.288329  loss_kpt: 0.288329  acc_pose: 0.763942
# 11/01 21:05:36 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 21:05:53 - mmengine - INFO - Epoch(train)   [24][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:48:29  time: 0.341704  data_time: 0.125464  memory: 5730  loss: 0.289445  loss_kpt: 0.289445  acc_pose: 0.800439
# 11/01 21:06:09 - mmengine - INFO - Epoch(train)   [24][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:48:48  time: 0.308929  data_time: 0.101166  memory: 5730  loss: 0.290272  loss_kpt: 0.290272  acc_pose: 0.791580
# 11/01 21:06:24 - mmengine - INFO - Epoch(train)   [24][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:48:16  time: 0.296868  data_time: 0.081140  memory: 5730  loss: 0.293153  loss_kpt: 0.293153  acc_pose: 0.794059
# 11/01 21:06:38 - mmengine - INFO - Epoch(train)   [24][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:47:33  time: 0.293963  data_time: 0.082760  memory: 5730  loss: 0.287881  loss_kpt: 0.287881  acc_pose: 0.833939
# 11/01 21:06:50 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 21:07:06 - mmengine - INFO - Epoch(train)   [25][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:47:39  time: 0.329927  data_time: 0.117122  memory: 5730  loss: 0.288818  loss_kpt: 0.288818  acc_pose: 0.834081
# 11/01 21:07:21 - mmengine - INFO - Epoch(train)   [25][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:46:59  time: 0.294697  data_time: 0.079618  memory: 5730  loss: 0.290583  loss_kpt: 0.290583  acc_pose: 0.817862
# 11/01 21:07:36 - mmengine - INFO - Epoch(train)   [25][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:46:16  time: 0.294048  data_time: 0.075547  memory: 5730  loss: 0.290956  loss_kpt: 0.290956  acc_pose: 0.818631
# 11/01 21:07:51 - mmengine - INFO - Epoch(train)   [25][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:45:55  time: 0.299189  data_time: 0.088173  memory: 5730  loss: 0.292596  loss_kpt: 0.292596  acc_pose: 0.770410
# 11/01 21:07:55 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 21:08:02 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 21:08:19 - mmengine - INFO - Epoch(train)   [26][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:46:36  time: 0.340832  data_time: 0.126141  memory: 5730  loss: 0.291170  loss_kpt: 0.291170  acc_pose: 0.782292
# 11/01 21:08:33 - mmengine - INFO - Epoch(train)   [26][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:45:33  time: 0.288639  data_time: 0.078394  memory: 5730  loss: 0.295608  loss_kpt: 0.295608  acc_pose: 0.786644
# 11/01 21:08:48 - mmengine - INFO - Epoch(train)   [26][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:44:48  time: 0.292969  data_time: 0.086793  memory: 5730  loss: 0.299142  loss_kpt: 0.299142  acc_pose: 0.815604
# 11/01 21:09:03 - mmengine - INFO - Epoch(train)   [26][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:44:00  time: 0.292082  data_time: 0.083918  memory: 5730  loss: 0.296941  loss_kpt: 0.296941  acc_pose: 0.803531
# 11/01 21:09:14 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 21:09:31 - mmengine - INFO - Epoch(train)   [27][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:44:37  time: 0.339390  data_time: 0.126550  memory: 5730  loss: 0.293670  loss_kpt: 0.293670  acc_pose: 0.808529
# 11/01 21:09:46 - mmengine - INFO - Epoch(train)   [27][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:44:53  time: 0.309132  data_time: 0.098069  memory: 5730  loss: 0.297124  loss_kpt: 0.297124  acc_pose: 0.760328
# 11/01 21:10:02 - mmengine - INFO - Epoch(train)   [27][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:45:03  time: 0.307759  data_time: 0.096628  memory: 5730  loss: 0.295498  loss_kpt: 0.295498  acc_pose: 0.787023
# 11/01 21:10:17 - mmengine - INFO - Epoch(train)   [27][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:44:32  time: 0.296571  data_time: 0.079551  memory: 5730  loss: 0.293172  loss_kpt: 0.293172  acc_pose: 0.862645
# 11/01 21:10:28 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 21:10:45 - mmengine - INFO - Epoch(train)   [28][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:45:50  time: 0.343987  data_time: 0.124326  memory: 5730  loss: 0.293999  loss_kpt: 0.293999  acc_pose: 0.789292
# 11/01 21:11:00 - mmengine - INFO - Epoch(train)   [28][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:45:06  time: 0.293039  data_time: 0.087929  memory: 5730  loss: 0.294173  loss_kpt: 0.294173  acc_pose: 0.780727
# 11/01 21:11:15 - mmengine - INFO - Epoch(train)   [28][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:44:44  time: 0.299168  data_time: 0.083274  memory: 5730  loss: 0.294004  loss_kpt: 0.294004  acc_pose: 0.792201
# 11/01 21:11:30 - mmengine - INFO - Epoch(train)   [28][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:44:09  time: 0.295331  data_time: 0.079817  memory: 5730  loss: 0.295323  loss_kpt: 0.295323  acc_pose: 0.776407
# 11/01 21:11:42 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 21:11:58 - mmengine - INFO - Epoch(train)   [29][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:45:00  time: 0.334027  data_time: 0.109017  memory: 5730  loss: 0.297186  loss_kpt: 0.297186  acc_pose: 0.776262
# ...
# 11/01 22:15:04 - mmengine - INFO - Epoch(train)   [79][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:36  time: 0.311412  data_time: 0.089947  memory: 5730  loss: 0.267318  loss_kpt: 0.267318  acc_pose: 0.823692
# 11/01 22:15:05 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:15:16 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:15:34 - mmengine - INFO - Epoch(train)   [80][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:59  time: 0.358898  data_time: 0.132739  memory: 5730  loss: 0.264354  loss_kpt: 0.264354  acc_pose: 0.825621
# 11/01 22:15:49 - mmengine - INFO - Epoch(train)   [80][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:42  time: 0.302517  data_time: 0.090405  memory: 5730  loss: 0.267774  loss_kpt: 0.267774  acc_pose: 0.804875
# 11/01 22:16:04 - mmengine - INFO - Epoch(train)   [80][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:36  time: 0.310756  data_time: 0.089162  memory: 5730  loss: 0.266848  loss_kpt: 0.266848  acc_pose: 0.824416
# 11/01 22:16:20 - mmengine - INFO - Epoch(train)   [80][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:38  time: 0.318071  data_time: 0.100392  memory: 5730  loss: 0.267217  loss_kpt: 0.267217  acc_pose: 0.835354
# 11/01 22:16:32 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:16:32 - mmengine - INFO - Saving checkpoint at 80 epochs
# 11/01 22:16:41 - mmengine - INFO - Epoch(val)   [80][50/54]    eta: 0:00:00  time: 0.122580  data_time: 0.051153  memory: 5730
# 11/01 22:16:41 - mmengine - INFO - Evaluating PCKAccuracy (normalized by ``"bbox_size"``)...
# 11/01 22:16:41 - mmengine - INFO - Epoch(val) [80][54/54]    PCK: 0.922246  data_time: 0.047191  time: 0.115997
# 11/01 22:16:41 - mmengine - INFO - The previous best checkpoint /n/groups/datta/6cam_keypoint_networks/mm_pose/Jonah/20241030_v1/rtmpose/rtmpose-m_8xb64-210e_ap10k-256x256_24-11-01-20-36-55/best_PCK_epoch_70.pth is removed
# 11/01 22:16:43 - mmengine - INFO - The best checkpoint with 0.9222 PCK at 80 epoch is saved to best_PCK_epoch_80.pth.
# 11/01 22:17:04 - mmengine - INFO - Epoch(train)   [81][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:03  time: 0.359591  data_time: 0.139275  memory: 5730  loss: 0.263897  loss_kpt: 0.263897  acc_pose: 0.851459
# 11/01 22:17:19 - mmengine - INFO - Epoch(train)   [81][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:49  time: 0.304640  data_time: 0.085809  memory: 5730  loss: 0.265989  loss_kpt: 0.265989  acc_pose: 0.776024
# 11/01 22:17:34 - mmengine - INFO - Epoch(train)   [81][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:39  time: 0.308014  data_time: 0.094642  memory: 5730  loss: 0.262210  loss_kpt: 0.262210  acc_pose: 0.825264
# 11/01 22:17:50 - mmengine - INFO - Epoch(train)   [81][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:33  time: 0.311521  data_time: 0.100825  memory: 5730  loss: 0.268995  loss_kpt: 0.268995  acc_pose: 0.896885
# 11/01 22:18:02 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:18:19 - mmengine - INFO - Epoch(train)   [82][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:52  time: 0.353154  data_time: 0.131874  memory: 5730  loss: 0.267860  loss_kpt: 0.267860  acc_pose: 0.829973
# 11/01 22:18:35 - mmengine - INFO - Epoch(train)   [82][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:49  time: 0.314158  data_time: 0.088328  memory: 5730  loss: 0.267194  loss_kpt: 0.267194  acc_pose: 0.807664
# 11/01 22:18:51 - mmengine - INFO - Epoch(train)   [82][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:59  time: 0.324759  data_time: 0.103008  memory: 5730  loss: 0.266990  loss_kpt: 0.266990  acc_pose: 0.811395
# 11/01 22:19:07 - mmengine - INFO - Epoch(train)   [82][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:50  time: 0.309677  data_time: 0.093051  memory: 5730  loss: 0.266676  loss_kpt: 0.266676  acc_pose: 0.812298
# 11/01 22:19:19 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:19:36 - mmengine - INFO - Epoch(train)   [83][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:04  time: 0.354514  data_time: 0.134071  memory: 5730  loss: 0.266531  loss_kpt: 0.266531  acc_pose: 0.797575
# 11/01 22:19:52 - mmengine - INFO - Epoch(train)   [83][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:00  time: 0.313863  data_time: 0.096441  memory: 5730  loss: 0.265919  loss_kpt: 0.265919  acc_pose: 0.809303
# 11/01 22:20:07 - mmengine - INFO - Epoch(train)   [83][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:48  time: 0.307072  data_time: 0.089368  memory: 5730  loss: 0.266288  loss_kpt: 0.266288  acc_pose: 0.861545
# 11/01 22:20:23 - mmengine - INFO - Epoch(train)   [83][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:39  time: 0.309645  data_time: 0.090278  memory: 5730  loss: 0.267013  loss_kpt: 0.267013  acc_pose: 0.844986
# 11/01 22:20:34 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:20:35 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:20:53 - mmengine - INFO - Epoch(train)   [84][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:56  time: 0.356212  data_time: 0.125814  memory: 5730  loss: 0.264424  loss_kpt: 0.264424  acc_pose: 0.787412
# 11/01 22:21:08 - mmengine - INFO - Epoch(train)   [84][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:46  time: 0.309464  data_time: 0.087524  memory: 5730  loss: 0.266171  loss_kpt: 0.266171  acc_pose: 0.869131
# 11/01 22:21:23 - mmengine - INFO - Epoch(train)   [84][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:35  time: 0.307571  data_time: 0.089453  memory: 5730  loss: 0.267488  loss_kpt: 0.267488  acc_pose: 0.839354
# 11/01 22:21:39 - mmengine - INFO - Epoch(train)   [84][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:36  time: 0.318252  data_time: 0.098995  memory: 5730  loss: 0.263427  loss_kpt: 0.263427  acc_pose: 0.849648
# 11/01 22:21:51 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:22:10 - mmengine - INFO - Epoch(train)   [85][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:10  time: 0.368877  data_time: 0.145828  memory: 5730  loss: 0.263216  loss_kpt: 0.263216  acc_pose: 0.814172
# 11/01 22:22:25 - mmengine - INFO - Epoch(train)   [85][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:56  time: 0.305552  data_time: 0.088515  memory: 5730  loss: 0.267291  loss_kpt: 0.267291  acc_pose: 0.852166
# 11/01 22:22:41 - mmengine - INFO - Epoch(train)   [85][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:58  time: 0.320102  data_time: 0.102900  memory: 5730  loss: 0.270832  loss_kpt: 0.270832  acc_pose: 0.824389
# 11/01 22:22:57 - mmengine - INFO - Epoch(train)   [85][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:08  time: 0.326317  data_time: 0.108992  memory: 5730  loss: 0.270325  loss_kpt: 0.270325  acc_pose: 0.838490
# 11/01 22:23:09 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:23:27 - mmengine - INFO - Epoch(train)   [86][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:32  time: 0.359708  data_time: 0.136571  memory: 5730  loss: 0.264919  loss_kpt: 0.264919  acc_pose: 0.791180
# 11/01 22:23:43 - mmengine - INFO - Epoch(train)   [86][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:30  time: 0.316202  data_time: 0.096797  memory: 5730  loss: 0.263934  loss_kpt: 0.263934  acc_pose: 0.827266
# 11/01 22:23:59 - mmengine - INFO - Epoch(train)   [86][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:21  time: 0.310099  data_time: 0.081144  memory: 5730  loss: 0.269062  loss_kpt: 0.269062  acc_pose: 0.826335
# 11/01 22:24:15 - mmengine - INFO - Epoch(train)   [86][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:21  time: 0.318613  data_time: 0.100251  memory: 5730  loss: 0.263677  loss_kpt: 0.263677  acc_pose: 0.873826
# 11/01 22:24:26 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:24:44 - mmengine - INFO - Epoch(train)   [87][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:34  time: 0.357230  data_time: 0.124673  memory: 5730  loss: 0.262726  loss_kpt: 0.262726  acc_pose: 0.850951
# 11/01 22:25:00 - mmengine - INFO - Epoch(train)   [87][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:25  time: 0.310584  data_time: 0.085251  memory: 5730  loss: 0.265826  loss_kpt: 0.265826  acc_pose: 0.832732
# 11/01 22:25:15 - mmengine - INFO - Epoch(train)   [87][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:07  time: 0.301755  data_time: 0.085491  memory: 5730  loss: 0.268256  loss_kpt: 0.268256  acc_pose: 0.839927
# 11/01 22:25:30 - mmengine - INFO - Epoch(train)   [87][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:54  time: 0.306849  data_time: 0.087468  memory: 5730  loss: 0.262749  loss_kpt: 0.262749  acc_pose: 0.827119
# 11/01 22:25:42 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:25:55 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:26:00 - mmengine - INFO - Epoch(train)   [88][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:02:02  time: 0.358843  data_time: 0.132760  memory: 5730  loss: 0.263459  loss_kpt: 0.263459  acc_pose: 0.838228
# 11/01 22:26:15 - mmengine - INFO - Epoch(train)   [88][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:44  time: 0.302604  data_time: 0.080221  memory: 5730  loss: 0.262655  loss_kpt: 0.262655  acc_pose: 0.843938
# 11/01 22:26:30 - mmengine - INFO - Epoch(train)   [88][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:33  time: 0.308401  data_time: 0.083254  memory: 5730  loss: 0.261802  loss_kpt: 0.261802  acc_pose: 0.798978
# 11/01 22:26:46 - mmengine - INFO - Epoch(train)   [88][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:29  time: 0.315388  data_time: 0.093114  memory: 5730  loss: 0.262194  loss_kpt: 0.262194  acc_pose: 0.806540
# 11/01 22:26:58 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:27:15 - mmengine - INFO - Epoch(train)   [89][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:27  time: 0.348890  data_time: 0.123417  memory: 5730  loss: 0.265158  loss_kpt: 0.265158  acc_pose: 0.836847
# 11/01 22:27:30 - mmengine - INFO - Epoch(train)   [89][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:10  time: 0.303261  data_time: 0.077521  memory: 5730  loss: 0.264950  loss_kpt: 0.264950  acc_pose: 0.794470
# 11/01 22:27:46 - mmengine - INFO - Epoch(train)   [89][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:01  time: 0.310660  data_time: 0.084689  memory: 5730  loss: 0.263878  loss_kpt: 0.263878  acc_pose: 0.824395
# 11/01 22:28:01 - mmengine - INFO - Epoch(train)   [89][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:00:56  time: 0.314623  data_time: 0.097614  memory: 5730  loss: 0.261368  loss_kpt: 0.261368  acc_pose: 0.787858
# 11/01 22:28:13 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:28:31 - mmengine - INFO - Epoch(train)   [90][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:01:06  time: 0.355280  data_time: 0.141489  memory: 5730  loss: 0.262892  loss_kpt: 0.262892  acc_pose: 0.780292
# 11/01 22:28:46 - mmengine - INFO - Epoch(train)   [90][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:00:54  time: 0.308746  data_time: 0.085239  memory: 5730  loss: 0.262625  loss_kpt: 0.262625  acc_pose: 0.858457
# 11/01 22:29:02 - mmengine - INFO - Epoch(train)   [90][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:00:37  time: 0.302811  data_time: 0.086880  memory: 5730  loss: 0.265185  loss_kpt: 0.265185  acc_pose: 0.815579
# 11/01 22:29:17 - mmengine - INFO - Epoch(train)   [90][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:00:27  time: 0.310475  data_time: 0.094532  memory: 5730  loss: 0.262036  loss_kpt: 0.262036  acc_pose: 0.826070
# 11/01 22:29:29 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:29:29 - mmengine - INFO - Saving checkpoint at 90 epochs
# 11/01 22:29:37 - mmengine - INFO - Epoch(val)   [90][50/54]    eta: 0:00:00  time: 0.121887  data_time: 0.051608  memory: 5730
# 11/01 22:29:38 - mmengine - INFO - Evaluating PCKAccuracy (normalized by ``"bbox_size"``)...
# 11/01 22:29:38 - mmengine - INFO - Epoch(val) [90][54/54]    PCK: 0.921850  data_time: 0.050326  time: 0.118140
# 11/01 22:29:56 - mmengine - INFO - Epoch(train)   [91][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:00:53  time: 0.370895  data_time: 0.151779  memory: 5730  loss: 0.262768  loss_kpt: 0.262768  acc_pose: 0.863125
# 11/01 22:30:12 - mmengine - INFO - Epoch(train)   [91][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:00:39  time: 0.306464  data_time: 0.092323  memory: 5730  loss: 0.263116  loss_kpt: 0.263116  acc_pose: 0.835228
# 11/01 22:30:27 - mmengine - INFO - Epoch(train)   [91][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:00:20  time: 0.301634  data_time: 0.081143  memory: 5730  loss: 0.262602  loss_kpt: 0.262602  acc_pose: 0.814273
# 11/01 22:30:42 - mmengine - INFO - Epoch(train)   [91][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:00:03  time: 0.303492  data_time: 0.082499  memory: 5730  loss: 0.263034  loss_kpt: 0.263034  acc_pose: 0.799968
# 11/01 22:30:53 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:31:11 - mmengine - INFO - Epoch(train)   [92][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 15:00:01  time: 0.352385  data_time: 0.122914  memory: 5730  loss: 0.263044  loss_kpt: 0.263044  acc_pose: 0.836533
# 11/01 22:31:17 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:31:26 - mmengine - INFO - Epoch(train)   [92][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 14:59:49  time: 0.308488  data_time: 0.087702  memory: 5730  loss: 0.264051  loss_kpt: 0.264051  acc_pose: 0.819779
# 11/01 22:31:42 - mmengine - INFO - Epoch(train)   [92][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 14:59:35  time: 0.305997  data_time: 0.091796  memory: 5730  loss: 0.264552  loss_kpt: 0.264552  acc_pose: 0.835649
# 11/01 22:31:57 - mmengine - INFO - Epoch(train)   [92][200/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 14:59:13  time: 0.299038  data_time: 0.082724  memory: 5730  loss: 0.267173  loss_kpt: 0.267173  acc_pose: 0.808879
# 11/01 22:32:08 - mmengine - INFO - Exp name: rtmpose-m_8xb64-210e_ap10k-256x256_20241101_203711
# 11/01 22:32:25 - mmengine - INFO - Epoch(train)   [93][ 50/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 14:59:03  time: 0.341729  data_time: 0.126198  memory: 5730  loss: 0.261984  loss_kpt: 0.261984  acc_pose: 0.834263
# 11/01 22:32:40 - mmengine - INFO - Epoch(train)   [93][100/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 14:58:38  time: 0.295273  data_time: 0.080864  memory: 5730  loss: 0.264968  loss_kpt: 0.264968  acc_pose: 0.777587
# 11/01 22:32:56 - mmengine - INFO - Epoch(train)   [93][150/241]  base_lr: 4.000000e-03 lr: 4.000000e-03  eta: 1 day, 14:58:27  time: 0.309783  data_time: 0.088935  memory: 5730  loss: 0.264121  loss_kpt: 0.264121  acc_pose: 0.834669

# %% [markdown]
# ### The config and path for running inference will be in the working directory

# %%
2+2
# Out:
# 4
